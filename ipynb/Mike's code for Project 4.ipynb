# %%
import re
import pandas as pd
import requests

# %%
def generate_category(category):
    '''
    format a category for insertion in to a wikipedia api call
    '''
    category = re.sub('\s','+',category)
    return category

# %%
def generate_query(category):
    '''
    Format an api call for requests
    '''
    query = """
            http://en.wikipedia.org/w/api.php?
            action=query&
            format=json&
            list=categorymembers&
            cmtitle=Category:{}& 
            cmlimit=max
            """.format(generate_category(category))
    query = re.sub('\s','',query)
    return query

# %%
def execute_category_query(category):
    '''
    Executes a category qeury and returns a 
    DataFrame of the category members
    '''
    
    r = requests.get(generate_query(category))
    response = r.json()
    return pd.DataFrame(response['query']['categorymembers'])

# %%
test = execute_category_query('machine learning')

# %%
test
# Out:
#      ns    pageid                                              title
# 0     0  43385931                                   Data exploration
# 1     0  49082762     List of datasets for machine learning research
# 2     0    233488                                   Machine learning
# 3     0  53587467                        Outline of machine learning
# 4     0  53198248                         Singular statistical model
# 5     0   3771060                                   Accuracy paradox
# 6     0  43808044                              Action model learning
# 7     0  28801798                 Active learning (machine learning)
# 8     0  45049676                       Adversarial machine learning
# 9     0  52642349                                               AIVA
# 10    0  30511763                                               AIXI
# 11    0  50773876                                Algorithm Selection
# 12    0  20890511                              Algorithmic inference
# 13    0  49242352                                            AlphaGo
# 14    0  19463198                            Apprenticeship learning
# 15    0  14003441                                 Bag-of-words model
# 16    0  31877832                                          Ball tree
# 17    0   9732182                                          Base rate
# 18    0  35867897   Bayesian interpretation of kernel regularization
# 19    0  40973765                              Bayesian optimization
# 20    0  50211107                    Bayesian structural time series
# 21    0  40678189                             Bias–variance tradeoff
# 22    0    205393                              Binary classification
# 23    0  50646178                                      Bing Predicts
# 24    0   1191936                                    Bongard problem
# 25    0  44439173                                Bradley–Terry model
# 26    0  53631046                                   Caffe (software)
# 27    0  39182554                          Catastrophic interference
# 28    0   8964665                                   Category utility
# 29    0  17114678                                         CBCL (MIT)
# ..   ..       ...                                                ...
# 198  14  33547387                  Category:Applied machine learning
# 199  14  42936114                Category:Artificial neural networks
# 200  14   1718975                         Category:Bayesian networks
# 201  14   1991254                 Category:Classification algorithms
# 202  14  22532673                          Category:Cluster analysis
# 203  14  34310097             Category:Computational learning theory
# 204  14  12932492       Category:Artificial intelligence conferences
# 205  14  33542714  Category:Data mining and machine learning soft...
# 206  14  42320378              Category:Datasets in machine learning
# 207  14  29549713                       Category:Dimension reduction
# 208  14   3985352                         Category:Ensemble learning
# 209  14    754055                   Category:Evolutionary algorithms
# 210  14   3061615                       Category:Genetic programming
# 211  14  29003796               Category:Inductive logic programming
# 212  14  12535256       Category:Kernel methods for machine learning
# 213  14  20924581                    Category:Latent variable models
# 214  14  19314112               Category:Learning in computer vision
# 215  14  36407925                         Category:Log-linear models
# 216  14  28004586                            Category:Loss functions
# 217  14  33547228               Category:Machine learning algorithms
# 218  14  44943481                   Category:Machine learning portal
# 219  14  47991509                     Category:Machine learning task
# 220  14  24059390                             Category:Markov models
# 221  14   3832584              Category:Machine learning researchers
# 222  14  52763829                   Category:Semisupervised learning
# 223  14  11737376   Category:Statistical natural language processing
# 224  14  40149461                     Category:Structured prediction
# 225  14  52763867                       Category:Supervised learning
# 226  14  31176997                   Category:Support vector machines
# 227  14  52763828                     Category:Unsupervised learning
#
# [228 rows x 3 columns]

# %%
category_mask = test['title'].str.contains('Category:')

# %%
test[~category_mask].head()
# Out:
#    ns    pageid                                           title
# 0   0  43385931                                Data exploration
# 1   0  49082762  List of datasets for machine learning research
# 2   0    233488                                Machine learning
# 3   0  53587467                     Outline of machine learning
# 4   0  53198248                      Singular statistical model

# %%
def remove_category(category):
    category = re.sub('Category:', '', category)
    return category

# %%
test[category_mask]['title'].apply(remove_category)[:10]
# Out:
# 198                     Applied machine learning
# 199                   Artificial neural networks
# 200                            Bayesian networks
# 201                    Classification algorithms
# 202                             Cluster analysis
# 203                Computational learning theory
# 204          Artificial intelligence conferences
# 205    Data mining and machine learning software
# 206                 Datasets in machine learning
# 207                          Dimension reduction
# Name: title, dtype: object

# %%
subcat_df_list = []

# %%
categories_to_query = test[category_mask]['title'].apply(remove_category).tolist()

# %%
categories_to_query
# Out:
# ['Applied machine learning',
#  'Artificial neural networks',
#  'Bayesian networks',
#  'Classification algorithms',
#  'Cluster analysis',
#  'Computational learning theory',
#  'Artificial intelligence conferences',
#  'Data mining and machine learning software',
#  'Datasets in machine learning',
#  'Dimension reduction',
#  'Ensemble learning',
#  'Evolutionary algorithms',
#  'Genetic programming',
#  'Inductive logic programming',
#  'Kernel methods for machine learning',
#  'Latent variable models',
#  'Learning in computer vision',
#  'Log-linear models',
#  'Loss functions',
#  'Machine learning algorithms',
#  'Machine learning portal',
#  'Machine learning task',
#  'Markov models',
#  'Machine learning researchers',
#  'Semisupervised learning',
#  'Statistical natural language processing',
#  'Structured prediction',
#  'Supervised learning',
#  'Support vector machines',
#  'Unsupervised learning']

# %%
for category in categories_to_query:
    subcat_df_list.append(execute_category_query(category))

# %%
subcat_df_list
# Out:
# [    ns    pageid                                   title
#  0    0  15795950                    Activity recognition
#  1    0  41916168                              AlchemyAPI
#  2    0  53631046                        Caffe (software)
#  3    0  49119569    Comparison of deep learning software
#  4    0  41916447                                 Cortica
#  5    0  34529351                      DARPA LAGR Program
#  6    0  43169442                          Deeplearning4j
#  7    0  38818825                                 Diffbot
#  8    0  41184517                            Google Brain
#  9    0  46222904                         Intel RealSense
#  10   0  35456221                                 IRCF360
#  11   0    705605                             Jabberwacky
#  12   0  31663650                                  Kaggle
#  13   0  51650259                                   Keras
#  14   0  23048428                                  Kinect
#  15   0  23762260  Language Acquisition Device (computer)
#  16   0  48976249                             MysteryVibe
#  17   0  34113322                               Nest Labs
#  18   0  52202762                                 Niki.ai
#  19   0   1643246                                 Numenta
#  20   0  42129549                                  OpenNN
#  21   0  50303345           Portable Format for Analytics
#  22   0   2876802        Predictive Model Markup Language
#  23   0  41917196     Quantum Artificial Intelligence Lab
#  24   0  52404701                            Quick, Draw!
#  25   0  31103500                        Reasoning system
#  26   0  27370710                          Sense Networks
#  27   0  35494317                       Sensorium Project
#  28   0    763951   Simultaneous localization and mapping
#  29   0  47509138                                 Skymind
#  30   0   4086271                              SmartMatch
#  31   0  26127201                               TD-Gammon
#  32   0  48508507                              TensorFlow
#  33   0  40914533                     Vicarious (company),
#       ns    pageid                                              title
#  0     0     21523                          Artificial neural network
#  1     0  28016652                Types of artificial neural networks
#  2     0  14179835                                Activation function
#  3     0   8220913                                            ADALINE
#  4     0  31663887              Adaptive neuro fuzzy inference system
#  5     0   3056879                          Adaptive resonance theory
#  6     0   4231161                                             ALOPEX
#  7     0  16167377                     Artificial Intelligence System
#  8     0    349771                                  Artificial neuron
#  9     0  51404222                                            Artisto
#  10    0   9054429                             Autoassociative memory
#  11    0   6836612                                        Autoencoder
#  12    0   1360091                                    Backpropagation
#  13    0  27569062                       Backpropagation through time
#  14    0  33025196                                              Bcpnn
#  15    0  17290783                   Bidirectional associative memory
#  16    0  49686608            Bidirectional recurrent neural networks
#  17    0   1166059                                  Boltzmann machine
#  18    0  53631046                                   Caffe (software)
#  19    0  39182554                          Catastrophic interference
#  20    0   2506529                            Cellular neural network
#  21    0   8160211           Cerebellar model articulation controller
#  22    0  38156432                                               CoDi
#  23    0   9583985                                  Committee machine
#  24    0  26266110                               Competitive learning
#  25    0  13526929            Compositional pattern-producing network
#  26    0   1532719                          Computational cybernetics
#  27    0   8402086                Computational neurogenetic modeling
#  28    0  54550729        Connectionist Temporal Classification (CTC)
#  29    0  42368614                 Convolutional Deep Belief Networks
#  ..   ..       ...                                                ...
#  100   0  41575347                                          Quickprop
#  101   0   2310753                              Radial basis function
#  102   0   9651443                      Radial basis function network
#  103   0   8278198                              Random neural network
#  104   0  37862937                        Rectifier (neural networks)
#  105   0   1706303                           Recurrent neural network
#  106   0  43705185                           Recursive neural network
#  107   0  10667750                                Reservoir computing
#  108   0  33742232                       Restricted Boltzmann machine
#  109   0   7950358                                              Rprop
#  110   0     76996                                Self-organizing map
#  111   0   3710117                            Semantic neural network
#  112   0     87210                                   Sigmoid function
#  113   0   6152185                                   Softmax function
#  114   0  10159567                             Spiking neural network
#  115   0  37652061  Stochastic neural analog reinforcement calculator
#  116   0   2070605                          Stochastic neural network
#  117   0  41027689                                Synaptic transistor
#  118   0  14405160                                    Synaptic weight
#  119   0   5099023                             Tensor product network
#  120   0  23594537                          Time delay neural network
#  121   0  28071238                                           U-matrix
#  122   0  18543448                    Universal approximation theorem
#  123   0  43502368                         Vanishing gradient problem
#  124   0  54133326                                            WaveNet
#  125   0   1853175                        Winner-take-all (computing)
#  126   0  43561218                                     Word embedding
#  127   0  47527969                                           Word2vec
#  128  14  49119651                             Category:Deep learning
#  129  14   3735046                   Category:Neural network software
#
#  [130 rows x 3 columns],
#      ns    pageid                            title
#  0    0    203996                 Bayesian network
#  1    0  42734031   Bayesian hierarchical modeling
#  2    0   1169985          Causal Markov condition
#  3    0   1242713         Dynamic Bayesian network
#  4    0   1194259                Influence diagram
#  5    0   4855682          Junction tree algorithm
#  6    0   2649330                  Latent variable
#  7    0   1169984                   Markov blanket
#  8    0   4855451                      Moral graph
#  9    0  15882673                   Plate notation
#  10   0  11228012  Variable-order Bayesian network
#  11   0   2461612      Variational message passing,
#       ns    pageid                                          title
#  0     0  32003319      (1+ε)-approximate nearest neighbor search
#  1     0    740955                       Calibration (statistics)
#  2     0    843901  Soft independent modelling of class analogies
#  3     0   1579244                     Statistical classification
#  4     0  27156903             Variable kernel density estimation
#  5     0   1645603                                       AdaBoost
#  6     0   4231161                                         ALOPEX
#  7     0  11288998                      Alternating decision tree
#  8     0   5481056                            Analogical modeling
#  9     0  24455245             Averaged one-dependence estimators
#  10    0     21523                      Artificial neural network
#  11    0  28016652            Types of artificial neural networks
#  12    0     90500                    Boosting (machine learning)
#  13    0  11448016                                     BrownBoost
#  14    0   1966814                                 C4.5 algorithm
#  15    0  20733961                          Cascading classifiers
#  16    0    170333                           Case-based reasoning
#  17    0   6609041     Chi-square automatic interaction detection
#  18    0   6558202                           Sukhotin's algorithm
#  19    0  34062152                              Classifier chains
#  20    0  18586131                                    Co-training
#  21    0  23642426                                     CoBoosting
#  22    0  13526929        Compositional pattern-producing network
#  23    0   6979740                          Conceptual clustering
#  24    0   2714979                              Decision boundary
#  25  118  54105853                          Draft:Decision stream
#  26    0    577003                         Decision tree learning
#  27    0  43342432                           Deductive classifier
#  28    0  13750669                               Elastic matching
#  29    0   3070571               Evolving classification function
#  ..  ...       ...                                            ...
#  55    0   7466947                     Multi-label classification
#  56    0  26338110                      Multiclass classification
#  57    0   3259720           Multifactor dimensionality reduction
#  58    0   2266644                          Multilayer perceptron
#  59    0   4433814                Multinomial logistic regression
#  60    0  13244280                 Multiple discriminant analysis
#  61    0  25257017              Multispectral pattern recognition
#  62    0     87339                         Naive Bayes classifier
#  63    0  35250304                    Nearest centroid classifier
#  64    0   7309022                        Nearest neighbor search
#  65    0  12656117                              Novelty detection
#  66    0  20420396                       One-class classification
#  67    0  24313042                  Optimal discriminant analysis
#  68    0    172777                                     Perceptron
#  69    0   2088675         Probabilistic latent semantic analysis
#  70    0   1611247                                   Probit model
#  71    0   1784975                           Quadratic classifier
#  72    0   9651443                  Radial basis function network
#  73    0   1363880                                  Random forest
#  74    0  30034676                         Random subspace method
#  75    0   4195092                       Relevance vector machine
#  76    0  45274436                 Rules Extraction System Family
#  77    0     65309                         Support vector machine
#  78    0   6069850                  Syntactic pattern recognition
#  79    0  31731737                   Textual case-based reasoning
#  80    0   8145581                       Whitening transformation
#  81    0  12693735                             Winnow (algorithm)
#  82   14  42936114            Category:Artificial neural networks
#  83   14  17594154                        Category:Decision trees
#  84   14   3985352                     Category:Ensemble learning
#
#  [85 rows x 3 columns],
#      ns    pageid                                             title
#  0    0    669675                                  Cluster analysis
#  1    0  45049111                               Archetypal analysis
#  2    0  26148908                             Behavioral clustering
#  3    0   1810201                                      Biclustering
#  4    0  42016100                                  Brown clustering
#  5    0  22562715                  Clustering high-dimensional data
#  6    0    547949                               Clustering illusion
#  7    0  21542452                              Consensus clustering
#  8    0  33391687                            Constrained clustering
#  9    0  21417820                            Correlation clustering
#  10   0   1409693                                        Dendrogram
#  11   0  22324566  Determining the number of clusters in a data set
#  12   0  47226218                          Farthest-first traversal
#  13   0  31346116                              Geographical cluster
#  14   0  39982437                                       Geworkbench
#  15   0   2421175                                            Medoid
#  16   0    871681                                     Mixture model
#  17   0  51800796                         WACA clustering algorithm
#  18  14  15325165              Category:Cluster analysis algorithms
#  19  14  30033882                      Category:Clustering criteria,
#      ns    pageid                                    title
#  0    0    383480              Algorithmic learning theory
#  1    0   3326106                          Bondy's theorem
#  2    0    387537            Computational learning theory
#  3    0   3326075                            Concept class
#  4    0  24364159                          Cover's theorem
#  5    0  44655565             Distribution learning theory
#  6    0  48833041           Error Tolerance (PAC learning)
#  7    0  52651586                          Growth function
#  8    0  41180634           Induction of regular languages
#  9    0   1299933     Language identification in the limit
#  10   0  44577560                           Occam learning
#  11   0    380008  Probably approximately correct learning
#  12   0  35887507                      Representer theorem
#  13   0   3119343               Sample exclusion dimension
#  14   0   1433659                            Shattered set
#  15   0   3326018                       Teaching dimension
#  16   0   1869181                Unique negative dimension
#  17   0    305843               Vapnik–Chervonenkis theory
#  18   0    305846                             VC dimension
#  19   0  14082746                    Win–stay, lose–switch
#  20   0   3326019                              Witness set,
#      ns    pageid                                              title
#  0    0  24714635         AAAI Conference on Artificial Intelligence
#  1    0  27562454                                              AI@50
#  2    0  38629606      Conference on Artificial General Intelligence
#  3    0  22663171  Conference on Knowledge Discovery and Data Mining
#  4    0   1175156  Conference on Neural Information Processing Sy...
#  5    0   1124646                                 Dartmouth workshop
#  6    0  19834151                                          ECML PKDD
#  7    0   3358541     European Conference on Artificial Intelligence
#  8    0  18586449       International Conference on Machine Learning
#  9    0   2614944  International Joint Conference on Artificial I...
#  10   0  39758073  International Meeting on Computational Intelli...
#  11   0  30401716              International Semantic Web Conference
#  12   0  36494971  Mexican International Conference on Artificial...
#  13   0  27898066                                   RuleML Symposium,
#       ns    pageid                                           title
#  0     0  54186633                                 Aika (software)
#  1     0  15345868                                          Angoss
#  2     0  32293536                                     Anne O'Tate
#  3     0  40023747                                    Apache Flume
#  4     0  37752641                                   Apache Giraph
#  5     0  18706674                                   Apache Mahout
#  6     0  49338480                                 Apache SystemML
#  7     0  49542443                             Aphelion (software)
#  8     0  37815827                                 Astrostatistics
#  9   118  51941252                                       Draft:Bob
#  10    0  53631046                                Caffe (software)
#  11    0  36466699                                   CellCognition
#  12    0  49119569            Comparison of deep learning software
#  13    0  49853144  Comparison of deep learning software/Resources
#  14    0  42088557                                          DADiSP
#  15    0   3634096                          Data Mining Extensions
#  16    0  13233200                                   DataDetective
#  17    0   5844314                           Deep Web Technologies
#  18    0  43169442                                  Deeplearning4j
#  19    0  45429428                                   Distributed R
#  20    0  38682282                                            Dlib
#  21    0  26471190                                           Encog
#  22    0  27193284                                            ELKI
#  23    0  29550075                       Feature Selection Toolbox
#  24    0    462546                                            FICO
#  25    0  47518866                                         Fluentd
#  26    0    413102                                    Folding@home
#  27    0  11270152       General Architecture for Text Engineering
#  28    0     48707                                      GNU Octave
#  29    0  33544408                                        GraphLab
#  ..  ...       ...                                             ...
#  58    0  39775648                  Programming with Big Data in R
#  59    0  38327135                                  Pipeline Pilot
#  60    0  42440937                              Piranha (software)
#  61    0  53480676                      Probabilistic Action Cores
#  62    0    376707                        R (programming language)
#  63    0   5100865                                      RapidMiner
#  64    0  24727697                                      Rattle GUI
#  65    0  49191856                                          Renjin
#  66    0    990677                                  SAS (software)
#  67    0  33490859                                    Scikit-learn
#  68    0  44358146                     Self-Service Semantic Suite
#  69    0   9517150                                Shogun (toolbox)
#  70    0  36089423                                SolveIT Software
#  71    0  42164234                                    Apache Spark
#  72    0  20588127                                    SPSS Modeler
#  73    0  39478785                      Tanagra (machine learning)
#  74    0  48508507                                      TensorFlow
#  75    0  41996200                    List of text mining software
#  76    0  42571226                        Torch (machine learning)
#  77    0   2422681                                            UIMA
#  78    0  36472550                                           VIGRA
#  79    0  34732646                                   Vowpal Wabbit
#  80    0  32867182                      Waffles (machine learning)
#  81    0   3829034                         Weka (machine learning)
#  82    0  40205956                                Wolfram Language
#  83    0     49024                             Wolfram Mathematica
#  84    0  49541331                                         Xgboost
#  85    0  43375904                                        Yooreeka
#  86    0  45639654                               Zeroth (software)
#  87   14  38708030       Category:Social network analysis software
#
#  [88 rows x 3 columns],
#     ns    pageid                                           title
#  0   0  49082762  List of datasets for machine learning research
#  1   0  52222085                            Arabic Speech Corpus
#  2   0  10477224                            Iris flower data set
#  3   0  54057693                           Persian Speech Corpus
#  4   0   1514392                                        Test set
#  5   0   5289626                                           TIMIT
#  6  14  16215923            Category:Datasets in computer vision,
#      ns    pageid                                     title
#  0    0    579867                  Dimensionality reduction
#  1    0  40892755         Canonical correspondence analysis
#  2    0  11594341                   Correspondence analysis
#  3    0  18379199         Detrended correspondence analysis
#  4    0  28476914                               Elastic map
#  5    0    242190                        Feature extraction
#  6    0   1179950                         Feature selection
#  7    0   1524599         Generalized canonical correlation
#  8    0   4196522      Generalized multidimensional scaling
#  9    0    598031            Independent component analysis
#  10   0   5978424       Kernel principal component analysis
#  11   2  54135111         User:Michael Hardy/Envelope model
#  12   0  24271629             Local tangent space alignment
#  13   0  11634012                Locality-sensitive hashing
#  14   0  34327576                    Low-rank approximation
#  15   0   1013159                 Multidimensional analysis
#  16   0    398786                  Multidimensional scaling
#  17   0   3259720      Multifactor dimensionality reduction
#  18   0  30928751  Multilinear principal component analysis
#  19   0  30909817             Multilinear subspace learning
#  20   0  24688532          Multiple correspondence analysis
#  21   0  31770835                 NOMINATE (scaling method)
#  22   0    309261        Nonlinear dimensionality reduction
#  23   0   2139778                   Ordination (statistics)
#  24   0    265008                     Preference regression
#  25   0     76340              Principal component analysis
#  26   0  37697003                           Random indexing
#  27   0  43932548                         Random projection
#  28   0  42962570                       Relationship square
#  29   0  40398868                Relief (feature selection)
#  30   0  42368490       Robust principal component analysis
#  31   0  13345571                            Sammon mapping
#  32   0     76996                       Self-organizing map
#  33   0  18387828             Semantic mapping (statistics)
#  34   0   1187410                    Semidefinite embedding
#  35   0  25444200                 Sliced inverse regression
#  36   0  18566488                                Sparse PCA
#  37   0  10274608                       Stress majorization
#  38   0  30096639            Sufficient dimension reduction
#  39   0  18964319                      Tucker decomposition
#  40  14  36425555                  Category:Factor analysis,
#      ns    pageid                        title
#  0    0  22212276            Ensemble learning
#  1    0  12304987     Ensembles of classifiers
#  2    0   1645603                     AdaBoost
#  3    0     90500  Boosting (machine learning)
#  4    0   1307911        Bootstrap aggregating
#  5    0  11448016                   BrownBoost
#  6    0  20733961        Cascading classifiers
#  7    0  21974688    Gaussian process emulator
#  8    0  26649339            Gradient boosting
#  9    0  17627465                   LogitBoost
#  10   0   9616434                      LPBoost
#  11   0  48643701             Out-of-bag error
#  12   0   1363880                Random forest
#  13   0  30034676       Random subspace method,
#      ns    pageid                                          title
#  0    0    190837                         Evolutionary algorithm
#  1    0  16132124                         Artificial development
#  2    0  33418313                Cellular evolutionary algorithm
#  3    0   8143131                                         CMA-ES
#  4    0  25839999                      Computer-automated design
#  5    0  44636079           Constructive cooperative coevolution
#  6    0  13478962                             Cultural algorithm
#  7    0  36186033                                    DarwinTunes
#  8    0   3132241                         Differential evolution
#  9    0   1514277                              Effective fitness
#  10   0    940033                             Evolution strategy
#  11   0   5701305                               Evolution window
#  12   0  15702071  Evolutionary acquisition of neural topologies
#  13   0  29768590  Evolutionary Algorithm for Landmark Detection
#  14   0    213371                               Evolutionary art
#  15   0  26996847           Evolutionary multimodal optimization
#  16   0   7682980                             Evolutionary music
#  17   0    460689                       Evolutionary programming
#  18   0   3105175                                Evolved antenna
#  19   0  22142854                          Fitness approximation
#  20   0   9210345                            Gaussian adaptation
#  21   0   1098818                    Gene expression programming
#  22   0     12424                            Genetic programming
#  23   0   3558944                         Genetic representation
#  24   0   5609640                          Grammatical evolution
#  25   0  21573718                                      HyperNEAT
#  26   0  31405724                     IPO underpricing algorithm
#  27   0  34114298                     Java Grammatical Evolution
#  28   0    854461                     Learning classifier system
#  29   0  33965201                                       Melomics
#  30   0   3989208                              Memetic algorithm
#  31   0  26613882                              Meta-optimization
#  32   0  47623626                   Multi expression programming
#  33   0  32171561                     Natural evolution strategy
#  34   0    440706                                 Neuroevolution
#  35   0    344922        Neuroevolution of augmenting topologies
#  36   0    337083                    Particle swarm optimization
#  37   0  25056220               Promoter based genetic algorithm
#  38   0  34137622                         Reward-based selection
#  39   0   1556830                 Speciation (genetic algorithm)
#  40  14  37176176           Category:Gene expression programming
#  41  14    868737                    Category:Genetic algorithms
#  42  14   3061615                   Category:Genetic programming
#  43  14  51088850        Category:Nature-inspired metaheuristics
#  44   6  11394448                            File:Efficiency.GIF
#  45   6  10385269                        File:Mountain crest.GIF,
#      ns    pageid                         title
#  0    0     12424           Genetic programming
#  1    0    463838                       Eurisko
#  2    0   1098818   Gene expression programming
#  3    0   4375576             Grammar induction
#  4    0  34114298    Java Grammatical Evolution
#  5    0   1217294    Linear genetic programming
#  6    0  47623626  Multi expression programming
#  7    0   5999404              Joseph Nechvatal
#  8    0   1514696              Parity benchmark
#  9    0  31726662        Santa Fe Trail problem
#  10   0  17808671   Schema (genetic algorithms)
#  11   0  42922637           Symbolic regression,
#     ns    pageid                                title
#  0   0     54069          Inductive logic programming
#  1   0  39812166  Anti-unification (computer science)
#  2   0  16378228        First Order Inductive Learner
#  3   0    993979                          Golem (ILP)
#  4   0   9605764                               PROGOL,
#      ns    pageid                                title
#  0    0   6855527                        Fisher kernel
#  1    0    302944                     Gaussian process
#  2    0    987959                       Gramian matrix
#  3    0  39419087                         Graph kernel
#  4    0  42253995               Kernel adaptive filter
#  5    0  23634548                    Kernel eigenvoice
#  6    0   3424576                        Kernel method
#  7    0  42247256     Kernel methods for vector output
#  8    0  41485209                    Kernel perceptron
#  9    0   5978424  Kernel principal component analysis
#  10   0  48832912       Low Rank Matrix Approximations
#  11   0  37619227                    Polynomial kernel
#  12   0  38652210         Radial basis function kernel
#  13   0   4195092             Relevance vector machine
#  14   0  27618564                        String kernel
#  15  14  31176997     Category:Support vector machines,
#      ns    pageid                                   title
#  0    0   2649330                         Latent variable
#  1    0   4237572                   Latent variable model
#  2    0   1145683                         Raymond Cattell
#  3    0  34308675                  Common-method variance
#  4    0  16369738                 Doubly stochastic model
#  5    0  34073580                     Dynamic topic model
#  6    0  48673924        Dynamic unobserved effects model
#  7    0    253492                         Factor analysis
#  8    0  31601081                 Factor regression model
#  9    0  34422496              First-difference estimator
#  10   0    420159                    Item response theory
#  11   0   4094720                      Latent class model
#  12   0   4605351             Latent Dirichlet allocation
#  13   0    689427                Latent semantic analysis
#  14   0   9269164                      Local independence
#  15   0  37409460                  Measurement invariance
#  16   0    871681                           Mixture model
#  17   0  21890593                       Nuisance variable
#  18   0  28082011                     Pachinko allocation
#  19   0   1046736        Partial least squares regression
#  20   0   2088675  Probabilistic latent semantic analysis
#  21   0   2007748            Structural equation modeling
#  22   0  18253454          Theory of conjoint measurement
#  23   0  33802950                       Thurstonian model
#  24   0  28934119                             Topic model
#  25  14  36425555                Category:Factor analysis
#  26  14  29967998     Category:Structural equation models,
#     ns    pageid                        title
#  0   0     90500  Boosting (machine learning)
#  1   0  15261618          Constellation model
#  2   0  37771696                    ImageNets
#  3   0  15261672            One-shot learning,
#     ns    pageid                          title
#  0   0  15689191               Log-linear model
#  1   0  41853858  Generalized iterative scaling,
#     ns    pageid                                    title
#  0   0    442137                            Loss function
#  1   0  33100241                               Hinge loss
#  2   0  26357083                               Huber loss
#  3   0    201816                       Mean squared error
#  4   0   3244288            Mean squared prediction error
#  5   0  12738879              Sum of absolute differences
#  6   0  13178514  Sum of absolute transformed differences
#  7   0  22506548                    Taguchi loss function,
#      ns    pageid                                              title
#  0    0  27141012           Almeida–Pineda recurrent backpropagation
#  1    0   1360091                                    Backpropagation
#  2    0   1307911                              Bootstrap aggregating
#  3    0   8908590                                      CN2 algorithm
#  4    0  33986538                           Constructing skill trees
#  5    0  33548913                             Dehaene–Changeux model
#  6    0  34072669                                      Diffusion map
#  7    0  14333272                 Dominance-based rough set approach
#  8    0    342855                               Dynamic time warping
#  9    0  27141248                              Error-driven learning
#  10   0  26996847               Evolutionary multimodal optimization
#  11   0    470752                 Expectation–maximization algorithm
#  12   0   1977119                                            FastICA
#  13   0   9292749                         Forward–backward algorithm
#  14   0  27116291                                            GeneRec
#  15   0  12986391          Genetic Algorithm for Rule Set Production
#  16   0  30867546                        Growing self-organizing map
#  17   0   9114200                                               HEXQ
#  18   0  44738576                       Hyper basis function network
#  19   0  18990485                                          IDistance
#  20   0   1775388                      K-nearest neighbors algorithm
#  21   0  42247256                   Kernel methods for vector output
#  22   0   5978424                Kernel principal component analysis
#  23   0   7049330                                             Leabra
#  24   0   1796414                          Linde–Buzo–Gray algorithm
#  25   0  27321681                               Local outlier factor
#  26   0  45378845                             Logic learning machine
#  27   0  17627465                                         LogitBoost
#  28   0  44578554                  Loss functions for classification
#  29   0  34053961                                 Manifold alignment
#  30   0   8471575               Minimum redundancy feature selection
#  31   0  54238535                                 Mixture of experts
#  32   0  44635680                           Multiple kernel learning
#  33   0   3681279                  Non-negative matrix factorization
#  34   0  19892153                            Online machine learning
#  35   0  48643701                                   Out-of-bag error
#  36   0  27193055     Prefrontal cortex basal ganglia working memory
#  37   0  26891474                                               PVLV
#  38   0   1281850                                         Q-learning
#  39   0  20352269        Quadratic unconstrained binary optimization
#  40   0  41929726                                Query level feature
#  41   0  41575347                                          Quickprop
#  42   0   9651443                      Radial basis function network
#  43   0  25868700             Randomized weighted majority algorithm
#  44   0     66294                             Reinforcement learning
#  45   0  54879513  Repeated Incremental Pruning to Produce Error ...
#  46   0   7950358                                              Rprop
#  47   0  51997474                        Rule-based machine learning
#  48   0  34073367                                     Skill chaining
#  49   0  18566488                                         Sparse PCA
#  50   0  10584297                   State-Action-Reward-State-Action
#  51   0   1180641                        Stochastic gradient descent
#  52   0  53985910                                     Structured kNN
#  53   0  39758474        T-distributed stochastic neighbor embedding
#  54   0   1209759                       Temporal difference learning
#  55   0  34255982                               Wake-sleep algorithm
#  56   0   6025658                        Weighted Majority Algorithm
#  57  14    868737                        Category:Genetic algorithms,
#      ns    pageid                                       title
#  0  100  44943378     Portal:Machine learning/Related portals
#  1  100  44942962  Portal:Machine learning/Selected biography,
#     ns  pageid                          title
#  0   0  602401      Facial recognition system
#  1   0  203619        Handwriting recognition
#  2   0  265421              Inverted pendulum
#  3   0   49091  Optical character recognition
#  4   0   29468             Speech recognition,
#      ns    pageid                             title
#  0    0  22022581                      Markov model
#  1    0  33785111            Absorbing Markov chain
#  2    0    479884           Algorithmic composition
#  3    0    822778              Baum–Welch algorithm
#  4    0   2580555                  Bernoulli scheme
#  5    0     41119                       Burst error
#  6    0  27447573         Dependability state model
#  7    0   2212867                  Detailed balance
#  8    0  11035198  Discrete phase-type distribution
#  9    0  11014633        Dynamic Markov compression
#  10   0   5235137   Dynamics of Markovian particles
#  11   0  11071463                      Entropy rate
#  12   0    195196         Examples of Markov chains
#  13   0   1072943                 Forward algorithm
#  14   0   9292749        Forward–backward algorithm
#  15   0    579390                   Gene prediction
#  16   0  39756603             Generalized filtering
#  17   0   1854663                           GLIMMER
#  18   0  20155750                     Google matrix
#  19   0     98770               Hidden Markov model
#  20   0  37809826       Interacting particle system
#  21   0   1232914        Iterative Viterbi decoding
#  22   0    180855                     Kalman filter
#  23   0   1911810                    Language model
#  24   0    174091                    Mark V. Shaney
#  25   0     60876                      Markov chain
#  26   0   1802160        Markov chain geostatistics
#  27   0    236801          Markov chain Monte Carlo
#  28   0  11491735                  Markov partition
#  29   0    306422                   Markov property
#  30   0  22999330     Markov switching multifractal
#  31   0   3517732          Markovian discrimination
#  32   0  27900233      Maximum-entropy Markov model
#  33   0   7025924           Models of DNA evolution
#  34   0   4066308       Multiple sequence alignment
#  35   0  26334893                          PageRank
#  36   0    746912            Part-of-speech tagging
#  37   0    728760                   Path dependence
#  38   0  19852067              Pop music automation
#  39   0    239384                Population process
#  40   0   7941780              Quantum Markov chain
#  41   0     50578                   Queueing theory
#  42   0     66294            Reinforcement learning
#  43   0     38372                Snakes and Ladders
#  44   0   3772500     Soft output Viterbi algorithm
#  45   0  39033720     Stochastic cellular automaton
#  46   0    217313                 Stochastic matrix
#  47   0  53543792           Switching Kalman filter
#  48   0  12663005                       Transiogram
#  49   0  11228012   Variable-order Bayesian network
#  50   0  10770999       Variable-order Markov model
#  51   0    228015                 Viterbi algorithm
#  52  14  31813917     Category:Hidden Markov models
#  53  14  22718453          Category:Markov networks,
#      ns    pageid                                     title
#  0    0  54273277                           Alexei A. Efros
#  1    0  30783354                    Christopher G. Atkeson
#  2    0  20768311                              Pierre Baldi
#  3    0  47749536                             Yoshua Bengio
#  4    0  23441140                               Léon Bottou
#  5    0   4909283                               Leo Breiman
#  6    0   1562996                         Selmer Bringsjord
#  7    0  24021705                            Alberto Broggi
#  8    0  13515303                           Jaime Carbonell
#  9    0  11172734  Michael Collins (computational linguist)
#  10   0  33737411                            Corinna Cortes
#  11   0  46508944                          Armin B. Cremers
#  12   0  41919563                          Nando de Freitas
#  13   0  28899211                   Ofer Dekel (researcher)
#  14   0   5841495                           Ernst Dickmanns
#  15   0  51344878                      Thomas G. Dietterich
#  16   0  47790413                            Pedro Domingos
#  17   0  38617753                              Oren Etzioni
#  18   0  10371071                               Peter Flach
#  19   0  52586387                             Gary B. Fogel
#  20   0  40671069                        Jerome H. Friedman
#  21   0   4103883                    Luca Maria Gambardella
#  22   0  40587850                               Lise Getoor
#  23   0   6937286                         Zoubin Ghahramani
#  24   0  38968150                               Rayid Ghani
#  25   0  13428111                              Ben Goertzel
#  26   0  51213339                            Ian Goodfellow
#  27   0  54074115                                Lingyun Gu
#  28   0   3259263                            Demis Hassabis
#  29   0  35425965                             Trevor Hastie
#  ..  ..       ...                                       ...
#  51   0  35119817                           Yasuo Matsuyama
#  52   0  31240897                           Andrew McCallum
#  53   0  33275304                           Tom M. Mitchell
#  54   0  20976642                             Mehryar Mohri
#  55   0   7895245                         Stephen Muggleton
#  56   0  51876287                       Klaus-Robert Müller
#  57   0  16907430                             Hartmut Neven
#  58   0  25277512                                 Andrew Ng
#  59   0  29333275                                 Erkki Oja
#  60   0  10246907                           Steve Omohundro
#  61   0  15800444                               Barney Pell
#  62   0  43532494                             Pietro Perona
#  63   0   4373337                              Ross Quinlan
#  64   0   6608281                           Brian D. Ripley
#  65   0  51990887             Lior Ron (business executive)
#  66   0    405484                        Jürgen Schmidhuber
#  67   0   1368665                        Bernhard Schölkopf
#  68   0  53773102                            Stefano Soatto
#  69   0   7582832                            Karl Steinbuch
#  70   0  47086977                       Salvatore J. Stolfo
#  71   0  51097862                            Ilya Sutskever
#  72   0  10435998                              Katia Sycara
#  73   0  42547620                                Ben Taskar
#  74   0   3538953                           Sebastian Thrun
#  75   0    209673                           Vladimir Vapnik
#  76   0     52469                           Stephen Wolfram
#  77   0  44743346                                 Eric Xing
#  78   0  51098008                             Richard Zemel
#  79   0  54175354                              Arthur Zimek
#  80   0   7449800                           Jacek M. Zurada
#
#  [81 rows x 3 columns],
#     ns    pageid                         title
#  0   0  11273721  Hierarchical temporal memory,
#      ns    pageid                                   title
#  0    0  13805160                      Stochastic grammar
#  1    0  17110513                      Additive smoothing
#  2    0  42016100                        Brown clustering
#  3    0   5825553               Collostructional analysis
#  4    0   2284104                       Dissociated press
#  5    0  34073580                     Dynamic topic model
#  6    0   4011785                                F1 score
#  7    0   2229040                 Factored language model
#  8    0     87030                        Glottochronology
#  9    0  30533678         Interactive machine translation
#  10   0   4561188                       Frederick Jelinek
#  11   0  13911197                   Katz's back-off model
#  12   0   1911810                          Language model
#  13   0   4605351             Latent Dirichlet allocation
#  14   0  17878029               Markov information source
#  15   0   3517732                Markovian discrimination
#  16   0  27900233            Maximum-entropy Markov model
#  17   0   1661566                Natural Language Toolkit
#  18   0  17378052                     Noisy channel model
#  19   0   6026708                    Noisy text analytics
#  20   0  30972465                                 OpenNLP
#  21   0  28082011                     Pachinko allocation
#  22   0   2088675  Probabilistic latent semantic analysis
#  23   0   7498882                        Sinkov statistic
#  24   0   4558491         Statistical machine translation
#  25   0   7024544                     Statistical parsing
#  26   0   7271261                   Statistical semantics
#  27   0    299329         Stochastic context-free grammar
#  28   0  29895551        Synchronous context-free grammar
#  29   0    318439                             Text mining
#  30   0   2057290                                  Tf–idf
#  31   0  28934119                             Topic model
#  32   0   2061486                          Trigram tagger
#  33   0   3656587                 Variable rules analysis
#  34   0  13125238                        Writer invariant
#  35  14  42452485              Category:Language modeling,
#     ns    pageid                              title
#  0   0  28255458      Constrained conditional model
#  1   0  53985910                     Structured kNN
#  2   0  27260435              Structured prediction
#  3   0  20027065  Structured support vector machine
#  4  14  22691076          Category:Graphical models,
#     ns    pageid                         title
#  0   0  33742232  Restricted Boltzmann machine,
#     ns    pageid                                              title
#  0   0     65309                             Support vector machine
#  1   0  33100241                                         Hinge loss
#  2   0  26849824               Least squares support vector machine
#  3   0  17707632                          Margin (machine learning)
#  4   0  34060917                                        Ranking SVM
#  5   0  35857112  Regularization perspectives on support vector ...
#  6   0  20154492                    Sequential minimal optimization
#  7   0  20027065                  Structured support vector machine,
#      ns    pageid                            title
#  0    0    233497            Unsupervised learning
#  1    0   6836612                      Autoencoder
#  2    0  39177819               Cognitive computer
#  3    0  26266110             Competitive learning
#  4    0  50073184  Generative adversarial networks
#  5    0    404084                   Hebbian theory
#  6    0  11273721     Hierarchical temporal memory
#  7    0  33742232     Restricted Boltzmann machine
#  8    0     76996              Self-organizing map
#  9    0  48813654       Sparse dictionary learning
#  10   0     47805              Vector quantization]

# %%
def get_all_pages_rec(category):
    category_df = execute_category_query(category)
    pages_list = []
    category_mask = category_df['title'].str.contains('Category:')
    
    pages_df = category_df[~category_mask]
    pages_list.append(pages_df)
    
    categories = category_df[category_mask]['title']\
                            .str.replace('Category:','').tolist()
    if len(categories) > 0:
        for cat in categories:
            pages_list.append(get_all_pages_rec(cat))
    
    pages_df = pd.concat(pages_list)
    pages_df.reset_index()
    return pages_df

# %%
rec_test = get_all_pages_rec('machine learning')

# %%
rec_test.sample(5)
# Out:
#      ns    pageid                              title
# 93    0  41370976  Kernel embedding of distributions
# 154   0  37697003                    Random indexing
# 74    0  10711453             Long short-term memory
# 2     0  14179835                Activation function
# 27    0  43932548                  Random projection

# %%
rec_test.shape
# Out:
# (1606, 3)

# %%
rec_test.drop_duplicates().shape
# Out:
# (1104, 3)

# %%
get_all_pages_rec('business software')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'title'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-e70ec878172e> in <module>()
# ----> 1 get_all_pages_rec('business software')
#
# <ipython-input-27-67d00d715295> in get_all_pages_rec(category)
#       8     if len(categories) > 0:
#       9         for cat in categories:
# ---> 10             pages_list.append(get_all_pages_rec(cat))
#      11
#      12     pages_df = pd.concat(pages_list)
#
# <ipython-input-27-67d00d715295> in get_all_pages_rec(category)
#       8     if len(categories) > 0:
#       9         for cat in categories:
# ---> 10             pages_list.append(get_all_pages_rec(cat))
#      11
#      12     pages_df = pd.concat(pages_list)
#
# <ipython-input-27-67d00d715295> in get_all_pages_rec(category)
#       2     category_df = execute_category_query(category)
#       3     pages_list = []
# ----> 4     category_mask = category_df['title'].str.contains('Category:')
#       5     pages_df = category_df[~category_mask]
#       6     pages_list.append(pages_df)
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /opt/conda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /opt/conda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4433)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4279)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13742)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13696)()
#
# KeyError: 'title'

# %%
def get_whole_category (category):
    df = get_all_pages_rec(category)
    df = df.drop_duplicates().reset_index(drop=True)
    df['category'] = category
    return df

# %%
gwc_test = get_whole_category('machine learning')
